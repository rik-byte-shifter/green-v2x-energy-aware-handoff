# %% [markdown]
# # Green V2X — analysis
#
# Run `python main.py` from the project root, then load `results/simulation_results.json` for further analysis.

# %%
import json
from pathlib import Path

root = Path('..')
p = root / 'results' / 'simulation_results.json'
if p.exists():
    data = json.loads(p.read_text(encoding='utf-8'))
    print(list(data.keys()))
else:
    print('Run main.py first to generate results.')
